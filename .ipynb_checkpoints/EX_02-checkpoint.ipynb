# %%
import cv2 as cv
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

img = mpl.image.imread("image.jpg")
plt.title("Imagem Original")
plt.imshow(img)

# %%
# Representar um aglomerado de pixels os quais possuem diferentes coordenadas RGB
X = img.reshape(-1,3)
X = np.float32(X)

print(f"Height = {img.shape[0]} | Width = {img.shape[1]} | Channel = {img.shape[2]}")
print(f"Pixels = {X.shape[0]} | Coordinates = {X.shape[1]}")
# Out:
# 100.0
# Height = 575 | Width = 1024 | Channel = 3
# Pixels = 588800 | Coordinates = 3

# %%
# Definir um número de centroides
k = 4

criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 10, 1)
retval, labels, centers = cv.kmeans(X, k, None, criteria, 10, cv.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
segmented_data = centers[labels.flatten()]
print(labels.flatten())
segmented_image = segmented_data.reshape((img.shape))
 
plt.imshow(segmented_image)

kmeans = km(n_clusters=k, n_init=10).fit(X)
seg_img = kmeans.cluster_centers_[kmeans.labels_]


# kmeans.cluster_centers_: Vai mostrar a cor específica(coordenadas) para cada cluster
# kmeans.labels_: Vai mostrar qual cluster cada pixel é representado

# Juntando os dois, cada pixel vai ter as coordenadas exatas do seu respectivo cluster
# Voltando para o formato da imagem original

seg_img = seg_img.reshape(img.shape)
seg_img = np.unit8(seg_img)
plt.title("Imagem Segmentada")
plt.imshow(seg_img)
